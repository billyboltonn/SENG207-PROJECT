# %% [markdown]
#  # **SENG207 PROJECT**
# ## NAME: BILLY BOLTON
# ## INDEX NO: 10950166
# ## CLASS: MTEN DEPT

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
wine_data = pd.read_csv('./red_wine.csv')

# %%
wine_data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_data.head(10)
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9   0.076000
# 1            7.8              0.88         0.00             2.6   0.098000
# 2            7.8              0.76         0.04             2.3   0.092000
# 3           11.2              0.28         0.56             1.9   0.075000
# 4            7.4              0.70         0.00             1.9   0.076000
# 5            7.4              0.66         0.00             1.8   0.075000
# 6            7.9              0.60         0.06             1.6   0.087476
# 7            7.3              0.65         0.00             1.2   0.065000
# 8            7.8              0.58         0.02             2.0   0.073000
# 9            7.5              0.50         0.36             6.1   0.071000
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# ...

# %%
wine_data.tail(20)
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 1579            6.2             0.560         0.09             1.7      0.053
# 1580            7.4             0.350         0.33             2.4      0.068
# 1581            6.2             0.560         0.09             1.7      0.053
# 1582            6.1             0.715         0.10             2.6      0.053
# 1583            6.2             0.460         0.29             2.1      0.074
# 1584            6.7             0.320         0.44             2.4      0.061
# 1585            7.2             0.390         0.44             2.6      0.066
# 1586            7.5             0.310         0.41             2.4      0.065
# 1587            5.8             0.610         0.11             1.8      0.066
# 1588            7.2             0.660         0.33             2.5      0.068
# 1589            6.6             0.725         0.20             7.8      0.073
# ...

# %%
wine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1598 non-null   float64
#  1   volatile acidity      1598 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1595 non-null   float64
#  5   free sulfur dioxide   1598 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1598 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1598 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %%
wine_data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %%
wine_data.columns = wine_data.columns.str.replace(' ','_')

# %%
wine_data
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
mean_FA = wine_data.fixed_acidity.mean()
mean_VA = wine_data.volatile_acidity.mean()
mean_CA = wine_data.citric_acid.mean()
mean_RS = wine_data.residual_sugar.mean()
mean_C = wine_data.chlorides.mean()
mean_FSD = wine_data.free_sulfur_dioxide.mean()
mean_TSD = wine_data.total_sulfur_dioxide.mean()
mean_D = wine_data.density.mean()
mean_PH = wine_data.pH.mean()
mean_S = wine_data.sulphates.mean()
mean_A = wine_data.alcohol.mean()
mean_Q = wine_data.quality.mean()

# %%
wine_data.mean()
# Out:
# fixed_acidity            8.318335
# volatile_acidity         0.527747
# citric_acid              0.270976
# residual_sugar           2.538806
# chlorides                0.087476
# free_sulfur_dioxide     15.867334
# total_sulfur_dioxide    46.467792
# density                  0.996746
# pH                       3.311113
# sulphates                0.658149
# alcohol                 10.422983
# quality                  5.635795
# dtype: float64

# %%
print(f'The mean value of fixed_acidity is {mean_FA}')
print(f'The mean value of volatile_acidity is {mean_VA}')
print(f'The mean value of citric_acid is {mean_CA}')
print(f'The mean value of residual_suagr is {mean_RS}')
print(f'The mean value of chlorides is {mean_C}')
print(f'The mean value of free_sulfur_dioxide is {mean_FSD}')
print(f'The mean value of total_sulfur_dioxide is {mean_TSD}')
print(f'The mean value of density is {mean_D}')
print(f'The mean value of pH is {mean_PH}')
print(f'The mean value of sulphates is {mean_S}')
print(f'The mean value of alcohol is {mean_A}')
print(f'The mean value of quality is {mean_Q}')
# Out:
# The mean value of fixed_acidity is 8.318335419274094
# The mean value of volatile_acidity is 0.527747183979975
# The mean value of citric_acid is 0.2709756097560976
# The mean value of residual_suagr is 2.53880550343965
# The mean value of chlorides is 0.08747586206896552
# The mean value of free_sulfur_dioxide is 15.867334167709638
# The mean value of total_sulfur_dioxide is 46.46779237023139
# The mean value of density is 0.996745519399249
# The mean value of pH is 3.3111131957473416
# The mean value of sulphates is 0.6581488430268917
# The mean value of alcohol is 10.422983114446529
# The mean value of quality is 5.635794743429287

# %%
wine_data.isnull()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1594          False             False        False           False      False
# 1595          False             False        False           False      False
# 1596          False             False        False           False      False
# 1597          False             False        False           False      False
# 1598          False             False        False           False      False
#
# ...

# %%
wine_data.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1598.000000       1598.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740863          0.179092     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1595.000000          1598.000000           1599.000000  1598.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047117            10.459029             32.895324     0.001887
# ...

# %%
wine_data_mean_values = wine_data.mean()

# %%
wine_data_mean_values
# Out:
# fixed_acidity            8.318335
# volatile_acidity         0.527747
# citric_acid              0.270976
# residual_sugar           2.538806
# chlorides                0.087476
# free_sulfur_dioxide     15.867334
# total_sulfur_dioxide    46.467792
# density                  0.996746
# pH                       3.311113
# sulphates                0.658149
# alcohol                 10.422983
# quality                  5.635795
# dtype: float64

# %%
wine_data = wine_data.fillna(wine_data_mean_values)

# %%
wine_data
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
wine_data.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.318335          0.527747     0.270976        2.538806
# std         1.740318          0.179036     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087476            15.867334             46.467792     0.996746
# std       0.047058            10.455756             32.895324     0.001887
# ...

# %%
wine_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed_acidity         1599 non-null   float64
#  1   volatile_acidity      1599 non-null   float64
#  2   citric_acid           1599 non-null   float64
#  3   residual_sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free_sulfur_dioxide   1599 non-null   float64
#  6   total_sulfur_dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   float64
# dtypes: float64(12)
# memory usage: 150.0 KB

# %% [markdown]
# ## DATA STATISTICS

# %%
#data for pie chart
colours = ['orange', 'beige', 'yellow', 'green', 'blue', 'red', 'violet', 'black', 'pink', 'grey', 'brown', 'purple']
explode = (0.5, 0.5, 1, 1, 1, 0, 0, 0.5, 0, 0.5, 0, 0.5)
meanValues = [mean_FA, mean_VA, mean_CA, mean_RS, mean_C, mean_FSD, mean_TSD, mean_D, mean_PH, mean_S, mean_A, mean_Q]
meanTopics = ['FA',
              'VA',
              'CA',
              'RS',
              'C',
              'FSD',
              'TSD',
              'density',
              'pH',
              'sulphates',
              'alcohol',
              'quality']

# %%
xtitle = 'Column names'
ytitle = 'Mean values'
legendlabels = ['fixed_acidity(FA)',
               'volatile_acidity(VA)',
               'citric_acid(CA)',
               'residual_sugar(RS)',
               'chlorides(C)',
               'free_sulfur_dioxide(FSD)',
               'total_sulfur_dioxide(TSD)',
               'density',
               'pH',
               'sulphates',
               'alcohol',
               'quality']

# %%
labels = meanTopics
sizes = meanValues

# %%
#piechat plot of mean values of each series
plt.pie(sizes, labels=labels, explode=explode, autopct='%1.1f%%', colors=colours)
plt.axis('equal')
plt.legend(title='Index', labels=legendlabels, loc='best',)
plt.title('Mean Values for each column in a pie chart')
plt.figure(figsize=(15, 18))
plt.show()
